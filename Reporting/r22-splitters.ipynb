# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <link rel="stylesheet" href="styles.css">
  <script src="script.js"></script>
  <title>Vertical Splitter</title>
  <style>
  html,
  body {
    height: 100%;
    margin: 0;
    padding: 0;
  }
  
  .split-pane {
    display: flex;
    height: 100%;
  }
  
  .pane {
    flex: 1;
    overflow-y: auto;
    padding: 20px;
  }
  .pane2 {
    background: blue;
  }
  .pane1 {
    background: green;
  }
  .splitter {
    width: 15px;
    cursor: column-resize;
    background-color: #eee;
  }
  </style>
</head>
<body>
  <div class="split-pane">
    <div class="pane pane1">
      <h2>Pane 1</h2>
      <p>This is the content of Pane 1.</p>
    </div>
    <div class="splitter" id="splitter"></div>
    <div class="pane pane2">
      <h2>Pane 2</h2>
      <p>This is the content of Pane 2.</p>
    </div>
  </div>
</body>
</html>

<script>
const splitter = document.getElementById('splitter');
let isDragging = false;

splitter.addEventListener('mousedown', function(e) {
  isDragging = true;
});

document.addEventListener('mousemove', function(e) {
  if (isDragging) {
    const yPos = e.clientY;
    const topPane = document.querySelector('.pane1');
    topPane.style.height = yPos + 'px';
  }
});

document.addEventListener('mouseup', function(e) {
  isDragging = false; 
});
</script>

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <link rel="stylesheet" href="styles.css">
  <script src="script.js"></script>
  <title>Two Panes with Movable Splitter</title>
  <style>
  body, html {
    height: 100%;
    margin: 0;
    padding: 0;
  }
  
  .split-pane {
    display: flex;
    height: 100%;
  }
  
  .pane {
    flex: 1;
    overflow-y: auto;
    padding: 20px;
  }
  
  .splitter {
    width: 5px;
    cursor: col-resize;
    background-color: #ccc;
  }
  
  </style>
</head>
<body>
    <h4>Extender</h4>
  <div class="split-pane">
    <div class="pane pane1">
      <!-- Content for pane 1 -->
      <h2>Pane 1</h2>
      <p>This is the content of pane 1.</p>
    </div>
    <div class="splitter" id='splitter'></div>
    <div class="pane pane2">
      <!-- Content for pane 2 -->
      <h2>Pane 2</h2>
      <p>This is the content of pane 2.</p>
    </div>
  </div>
  <script>
  // Enable splitter dragging functionality
  const splitter = document.getElementById('splitter');
  let isDragging = false;
  
  splitter.addEventListener('mousedown', function(e) {
      isDragging = true;
    });
    
    document.addEventListener('mousemove', function(e) {
        if (isDragging) {
            alert('wow');
            const xPos = e.clientX;
            const leftPane = document.querySelector('.pane1');
            leftPane.style.width = xPos + 'px';
        }
    });
    
    document.addEventListener('mouseup', function(e) {
        isDragging = false;
    });
    
</script>
</body>
</html>
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <link rel="stylesheet" href="styles.css">
#   <script src="script.js"></script>
#   <title>Two Panes with Movable Splitter</title>
#   <style>
#   body, html {
#     height: 100%;
#     margin: 0;
#     padding: 0;
#   }
#
#   .split-pane {
#     display: flex;
#     height: 100%;
#   }
#
#   .pane {
#     flex: 1;
#     overflow-y: auto;
#     padding: 20px;
#   }
#
#   .splitter {
#     width: 5px;
#     cursor: col-resize;
#     background-color: #ccc;
#   }
#
#   </style>
# </head>
# <body>
#     <h4>Extender</h4>
#   <div class="split-pane">
#     <div class="pane pane1">
#       <!-- Content for pane 1 -->
#       <h2>Pane 1</h2>
#       <p>This is the content of pane 1.</p>
#     </div>
#     <div class="splitter" id='splitter'></div>
#     <div class="pane pane2">
#       <!-- Content for pane 2 -->
#       <h2>Pane 2</h2>
# ...

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <link rel="stylesheet" href="styles.css">
  <script src="script.js"></script>
  <title>Two Panes with Movable Splitter</title>
  <style>
  <!-- insert styles here -->
  // Variables
  $black: #3C3530;
  $green: #AACD6E;
  $gray: #C5C6B6;
  
  html {
    box-sizing: border-box;
    font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Helvetica, Arial, "PingFang TC", "Heiti TC", 微軟正黑體, sans-serif;
    font-size: 16px;
    -webkit-font-smoothing: antialiased;
  }
  
  *,
  *:before,
  *:after {
    box-sizing: inherit;
  }
  
  body {
    width: 100%;
    height: 100vh;
    margin: 0;
    padding: 0;
  }
  
  .container {
    display: flex;
    width: 100%;
    height: 100%;
  }
  
  .split__left {
    width: 50%;
    background-color: $green;
  }
  
  .split__right {
    flex: 1; // the right panel will stretch the bg color
    background-color: $gray;
  }
  
  .split__bar {
    background-color: $black;
    width: 15px;
    height: 100%;
    cursor: col-resize;
  }
  
  </style>
</head>
<body>
  <hr>
  <!-- insert html here -->
  <div class="container split">
  <div class="split__left"></div>
  <div class="split__bar"></div>
  <div class="split__right"></div>
</div>
  <hr>
</body>
</html>
<script>
  <!-- insert js here -->
  const bar = document.querySelector('.split__bar');
  const left = document.querySelector('.split__left');
  let mouse_is_down = false;
  
  bar.addEventListener('mousedown', (e) => {
    mouse_is_down = true;
  })
  
  document.addEventListener('mousemove', (e) => {
    if (!mouse_is_down) return;
  
    left.style.width = `${e.clientX}px`;
  })
  
  document.addEventListener('mouseup', () => {
    mouse_is_down = false;
  })
</script>
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <link rel="stylesheet" href="styles.css">
#   <script src="script.js"></script>
#   <title>Two Panes with Movable Splitter</title>
#   <style>
#   <!-- insert styles here -->
#   // Variables
#   $black: #3C3530;
#   $green: #AACD6E;
#   $gray: #C5C6B6;
#
#   html {
#     box-sizing: border-box;
#     font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Helvetica, Arial, "PingFang TC", "Heiti TC", 微軟正黑體, sans-serif;
#     font-size: 16px;
#     -webkit-font-smoothing: antialiased;
#   }
#
#   *,
#   *:before,
#   *:after {
#     box-sizing: inherit;
#   }
#
#   body {
#     width: 100%;
#     height: 100vh;
#     margin: 0;
#     padding: 0;
#   }
#
#   .container {
#     display: flex;
#     width: 100%;
#     height: 100%;
#   }
#
#   .split__left {
#     width: 50%;
#     background-color: $green;
#   }
#
# ...

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <link rel="stylesheet" href="styles.css">
  <script src="script.js"></script>
  <title>Two Panes with Movable Splitter</title>
  <style>
  <!-- insert styles here -->

  </style>
</head>
<body>
  <hr>
  <!-- insert html here -->

  <hr>
</body>
</html>
<script>
  <!-- insert js here -->

</script>

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <link rel="stylesheet" href="styles.css">
  <script src="script.js"></script>
  <title>Two Panes with Movable Splitter</title>
  <style>
        
    html {
        box-sizing: border-box;
        font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Helvetica, Arial, "PingFang TC", "Heiti TC", 微軟正黑體, sans-serif;
        font-size: 16px;
        -webkit-font-smoothing: antialiased;
        
        --black: #3C3530;
        --green: #AACD6E;
        --gray: #C5C6B6;
    }
    *,
    *:before,
    *:after {
        box-sizing: inherit;
    }
    
    body {
        width: 100%;
    height: 100vh;
    margin: 0;
    padding: 0;
  }
  .main-box {
    width: 500px;
    height: 500px;
  }
  .container {
    display: flex;
    width: 100%;
    height: 100%;
  }
  
  .split__left {
    width: 50%;
    background-color: var(--green);
  }
  
  .split__right {
    flex: 1; 
    background-color: var(--gray);
  }
  
  .split__bar {
    background-color: var(--black);
    width: 15px;
    height: 100%;
    cursor: col-resize;
  }
  </style>
</head>
<body>
<!-- insert html here -->
<div class="main-box">
  <hr>
    <div class="container split">
      <div class="split__left"></div>
      <div class="split__bar"></div>
      <div class="split__right"></div>
    </div>
    <hr>
  </div>
  <script language=javascript type="text/javascript">
  const bar = document.querySelector('.split__bar');
  const left = document.querySelector('.split__left');
  let mouse_is_down = false;
  
  bar.addEventListener('mousedown', (e) => {
    mouse_is_down = true;
  })
  
  document.addEventListener('mousemove', (e) => {
    if (!mouse_is_down) return;
    left.style.width = `${e.clientX}px`;
  })
  
  document.addEventListener('mouseup', () => {
    mouse_is_down = false;
  })
</script>
</body>
</html>
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <link rel="stylesheet" href="styles.css">
#   <script src="script.js"></script>
#   <title>Two Panes with Movable Splitter</title>
#   <style>
#
#     html {
#         box-sizing: border-box;
#         font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, Helvetica, Arial, "PingFang TC", "Heiti TC", 微軟正黑體, sans-serif;
#         font-size: 16px;
#         -webkit-font-smoothing: antialiased;
#
#         --black: #3C3530;
#         --green: #AACD6E;
#         --gray: #C5C6B6;
#     }
#     *,
#     *:before,
#     *:after {
#         box-sizing: inherit;
#     }
#
#     body {
#         width: 100%;
#     height: 100vh;
#     margin: 0;
#     padding: 0;
#   }
#   .main-box {
#     width: 500px;
#     height: 500px;
#   }
#   .container {
#     display: flex;
#     width: 100%;
#     height: 100%;
#   }
#
#   .split__left {
# ...
